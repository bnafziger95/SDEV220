# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
even = [number for number in range(10) if number %2 == 0]
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %%
life = {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': [], 'emus': []},
        'plants': {},
        'other': {}}

# %%
print(life.keys())
# Out:
# dict_keys(['animals', 'plants', 'other'])

# %%
print(life['animals'].keys())
# Out:
# dict_keys(['cats', 'octopi', 'emus'])

# %%
for cat in life['animals']['cats']:
    print(cat)
# Out:
# Henri
# Grumpy
# Lucy

# %%
squares = {number: number ** 2 for number in range(10)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
odd = {number for number in range(10) if number %2 == 1}
print(odd)
# Out:
# {1, 3, 5, 7, 9}

# %%
titles = ['Creature of Habit', 'Crewel Fate', 'Sharks On a Plane']
plots = ['A nun turns into a monster', 'A haunted yarn shop', 'Check you exits']

movies = dict(zip(titles, plots))
print(movies)
# Out:
# {'Creature of Habit': 'A nun turns into a monster', 'Crewel Fate': 'A haunted yarn shop', 'Sharks On a Plane': 'Check you exits'}
