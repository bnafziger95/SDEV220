# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily

# %%
from zoo import hours
hours()
# Out:
# Open 9-5 daily

# %%
from zoo import hours as info
info()
# Out:
# Open 9-5 daily
